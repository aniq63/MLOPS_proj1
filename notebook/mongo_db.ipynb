# %%
import pandas as pd
import numpy as np
import pymongo

# %%
df = pd.read_csv('loan_data.csv')
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
data = df.to_dict(orient = 'records')

# %%
data
# Out:
# [{'person_age': 22.0,
#   'person_gender': 'female',
#   'person_education': 'Master',
#   'person_income': 71948.0,
#   'person_emp_exp': 0,
#   'person_home_ownership': 'RENT',
#   'loan_amnt': 35000.0,
#   'loan_intent': 'PERSONAL',
#   'loan_int_rate': 16.02,
#   'loan_percent_income': 0.49,
#   'cb_person_cred_hist_length': 3.0,
#   'credit_score': 561,
#   'previous_loan_defaults_on_file': 'No',
#   'loan_status': 1},
#  {'person_age': 21.0,
#   'person_gender': 'female',
#   'person_education': 'High School',
#   'person_income': 12282.0,
#   'person_emp_exp': 0,
#   'person_home_ownership': 'OWN',
#   'loan_amnt': 1000.0,
#   'loan_intent': 'EDUCATION',
#   'loan_int_rate': 11.14,
#   'loan_percent_income': 0.08,
#   'cb_person_cred_hist_length': 2.0,
#   'credit_score': 504,
#   'previous_loan_defaults_on_file': 'Yes',
#   'loan_status': 0},
#  {'person_age': 25.0,
#   'person_gender': 'female',
#   'person_education': 'High School',
#   'person_income': 12438.0,
# ...

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://aniqramzan5758_db_user:d7MX3LDqjVUluHpY@cluster0.kszzdi9.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %% [markdown]
# ### Push the data into database

# %%
rec = collection.insert_many(data)

# %% [markdown]
# ## Mongo DB concept explain
#
# Mongo db is non-sql database store a data in a JSON like format
#
# In mongo db we had cluster that work as server for our database
#
# In clusters we add databases
# -- Example databases of youtube
# 1. userDB
# 2. videoDB
# 3. ChannelsDB
#
# And in Database we had differennt collections
# -- Example of collection in databases
# Database: userDB
# 1. user
# 2. subscribe channels
